# %% [markdown]
# # Atacar una API desde Python
# Para la app2.py desarrollada durante la clase.

# %% [markdown]
# ### 1. Todos los libros

# %%
# Out:
# Status code: 200
# Headers: {'Content-Type': 'application/json', 'Content-Length': '13638', 'Server': 'Werkzeug/2.0.1 Python/3.8.8', 'Date': 'Tue, 05 Oct 2021 07:35:13 GMT'}
# Content: {
#   "books": [
#     [
#       null,
#       2014,
#       "Ann Leckie ",
#       "Ancillary Justice",
#       "The body lay naked and facedown, a deathly gray, spatters of blood staining the snow around it."
#     ],
#     [
#       null,
#       2013,
#       "John Scalzi",
#       "Redshirts",
#       "From the top of the large boulder he sat on, Ensign Tom Davis looked across the expanse of the cave, toward Captain Lucius Abernathy, Science Officer Q\u2019eeng and Chief Engineer Paul West perched on a second, larger boulder, and thought, Well, this sucks."
#     ],
#     [
#       null,
#       2012,
#       "Jo Walton",
#       "Among Others",
#       "The Phurnacite factory in Abercwmboi killed all the trees for two miles around."
#     ],
#     [
#       null,
#       2011,
# ...

# %% [markdown]
# ### 2. Id como params

# %%
# Out:
# Status code: 200
# Headers: {'Content-Type': 'application/json', 'Content-Length': '165', 'Server': 'Werkzeug/2.0.1 Python/3.8.8', 'Date': 'Tue, 05 Oct 2021 07:44:22 GMT'}
# Content: [
#   {
#     "author": "Samuel R. Delany",
#     "first_sentence": "to wound the autumnal city.",
#     "id": 2,
#     "published": "1975",
#     "title": "Dhalgren"
#   }
# ]
#
# Type content: <class 'str'>
# Content json: [{'author': 'Samuel R. Delany', 'first_sentence': 'to wound the autumnal city.', 'id': 2, 'published': '1975', 'title': 'Dhalgren'}]

# %% [markdown]
# ### 3. Title en la URL

# %%
# Out:
# Status code: 200
# Headers: {'Content-Type': 'application/json', 'Content-Length': '147', 'Server': 'Werkzeug/2.0.1 Python/3.8.8', 'Date': 'Tue, 05 Oct 2021 07:49:09 GMT'}
# Content: {
#   "author": "Samuel R. Delany",
#   "first_sentence": "to wound the autumnal city.",
#   "id": 2,
#   "published": "1975",
#   "title": "Dhalgren"
# }
#
# Type content: <class 'str'>
# Content json: {'author': 'Samuel R. Delany', 'first_sentence': 'to wound the autumnal city.', 'id': 2, 'published': '1975', 'title': 'Dhalgren'}

# %% [markdown]
# ### 4. Id en el body

# %%
# Out:
# Status code: 200
# Headers: {'Content-Type': 'application/json', 'Content-Length': '147', 'Server': 'Werkzeug/2.0.1 Python/3.8.8', 'Date': 'Tue, 05 Oct 2021 07:50:40 GMT'}
# Content: {
#   "author": "Samuel R. Delany",
#   "first_sentence": "to wound the autumnal city.",
#   "id": 2,
#   "published": "1975",
#   "title": "Dhalgren"
# }
#
# Type content: <class 'str'>
# Content json: {'author': 'Samuel R. Delany', 'first_sentence': 'to wound the autumnal city.', 'id': 2, 'published': '1975', 'title': 'Dhalgren'}
