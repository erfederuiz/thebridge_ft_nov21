# %% [markdown]
# # Exploratory Data Analysis with Seaborn
# Entender cómo se hacen las gráficas en python está muy bien, pero lo importante es saber cuándo usarlas. En este notebook no se pretende explicar todos los tipos de gráficas que hay (histogramas, scatter plots, heatmaps...), en primer lugar porque es imposible abarcarlo todo, y en segundo lugar porque hay que ir un paso atrás antes de elegir la gráfica, ya que tenemos que comprender de qué tipo son los datos y qué es lo que estamos buscando con cada gráfica.
#
# Por tanto, primero tendremos que identificar el tipo de los datos y cuántas variables vamos a representar
# - Una varibale numérica
# - Una variable categórica
# - Dos variables numércias
# - Tres o más variables numércias
# - Dos variables categóricas
# - Variables numércias y categóricas
#
# Teniendo claro esto, junto con un buen catálogo de gráficas, lo tendremos mucho más fácil.
#
# https://www.data-to-viz.com/

# %%
# Importamos todos los paquetes que vayamos a necesitar
from sklearn.datasets import load_iris
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Algunas configuraciones de los paquetes
pd.set_option("display.max_rows", 500) # Cuántas filas de los DataFrames nos "escupe" pandas en el Notebook
sns.set(color_codes=True)

import warnings
warnings.filterwarnings("ignore")

# %%
load_iris()['data']
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.2],
#        [5. , 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.6, 1.4, 0.1],
#        [4.4, 3. , 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5. , 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3. , 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5. , 3.3, 1.4, 0.2],
#        [7. , 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4. , 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1. ],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5. , 2. , 3.5, 1. ],
#        [5.9, 3. , 4.2, 1.5],
#        [6. , 2.2, 4. , 1. ],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3. , 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1. ],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4. , 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3. , 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3. , 5. , 1.7],
#        [6. , 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1. ],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.8, 2.7, 3.9, 1.2],
#        [6. , 2.7, 5.1, 1.6],
#        [5.4, 3. , 4.5, 1.5],
#        [6. , 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3. , 4.1, 1.3],
#        [5.5, 2.5, 4. , 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3. , 4.6, 1.4],
#        [5.8, 2.6, 4. , 1.2],
#        [5. , 2.3, 3.3, 1. ],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3. , 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3. , 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6. , 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [7.6, 3. , 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3. , 5.5, 2.1],
#        [5.7, 2.5, 5. , 2. ],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6. , 2.2, 5. , 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6. , 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3. , 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3. , 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3. , 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6. , 3. , 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3. , 5.2, 2.3],
#        [6.3, 2.5, 5. , 1.9],
#        [6.5, 3. , 5.2, 2. ],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3. , 5.1, 1.8]])

# %%
load_iris()['feature_names']
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
load_iris()['target_names'][load_iris()['target']]
# Out:
# array(['setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica'], dtype='<U10')

# %%
# Cargamos las features en un DataFrame:
iris_df = pd.DataFrame(load_iris()['data'], columns=load_iris()['feature_names'])

# Y añadimos la columna de especies:
iris_df['target'] = load_iris()['target_names'][load_iris()['target']]

# Cargamos tb el dataset del titanic
titanic_df = pd.read_csv('./data/titanic.csv', sep='\t')

# Cargamos los datos del supermarket sales
market_df = pd.read_csv('./data/supermarket_sales.csv', sep=',')

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
market_df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4
# 3  20:33      Ewallet  465.76                 4.761905       23.2880     8.4
# 4  10:37      Ewallet  604.17                 4.761905       30.2085     5.3

# %% [markdown]
# # Tipos de las variables
# Antes de representar cualquier variable es imprescindible comprender qué tipo de datos queremos representar.

# %% [markdown]
# ## 1. Análisis univariante
# ### 1.1 Variables cuantitativas
# Si queremos ver cómo se distribuyen los precios de venta de tickets del Titanic.
# #### Densidad
#
# [Documentación](https://seaborn.pydata.org/generated/seaborn.distplot.html)
#
# Este tipo de gráficas nos sirven para ver la distribución de los datos, donde se concentran más, ¿es dispersa? ¿tiene asimétrica? ¿por qué? ¿Hay outliers?

# %%
# %matplotlib inline
plt.figure(figsize=(10,5))
sns.histplot(titanic_df['Fare'], kde=False, color='g');

# %% [markdown]
# #### Histograma
# También podemos verlo en un histograma
#
# [Documentación](https://seaborn.pydata.org/generated/seaborn.distplot.html)
#
# Los histogramas dan la frecuencia de aparición de todos los valores. Muy similar al diagrama de densidad anterior. La diferencia es que ahora el eje `y` es un conteo, y no la probabilidad de aparición de los valores de la variable.

# %% [markdown]
# Podemos agrupar (visualmente) una variable numérica, como por ejemplo una categorización de los billetes

# %%
plt.figure(figsize=(5,5))
sns.histplot(titanic_df['Fare'], kde=False, color='g', bins=3);

# %% [markdown]
# #### Histograma + Densidad
#
# [Documentación](https://seaborn.pydata.org/generated/seaborn.distplot.html)

# %%
plt.figure(figsize=(10,5))
sns.distplot(titanic_df["Fare"],
            kde_kws={"color": "k", "lw": 3, "label": "KDE"},
            hist_kws={"histtype": "step", "linewidth": 3,
            "alpha": 1, "color": "g"});

# %% [markdown]
# Otra manera muy visual de ver la concentración de los valores es mediante el argumento `rug`

# %%
plt.figure(figsize=(5,5))
sns.distplot(titanic_df["Fare"],
             rug=True
            );

# %% [markdown]
# #### Boxplot
#
# [Colores de Matplotlib](https://matplotlib.org/3.1.0/gallery/color/named_colors.html)
#
# [Boxplot](https://seaborn.pydata.org/generated/seaborn.boxplot.html)<br>
# [Interpretar boxplots](https://www.analisisdedatos.org/single-post/2019/04/05/c%C3%B3mo-se-interpreta-un-diagrama-de-cajas-y-bigotes)<br>
# Los boxplots dan una información muy parecida a los gráficos vistos anteriormente, aunque en este caso destaca mucho más los outliers.

# %%
plt.figure(figsize=(20,5))
sns.boxplot(titanic_df["Fare"],color = 'sienna');

# %% [markdown]
# #### Violinplot
#
# [Colores de Matplotlib](https://matplotlib.org/3.1.0/gallery/color/named_colors.html)
#
# [Violinplot](https://seaborn.pydata.org/generated/seaborn.violinplot.html)
#
# Igual que un diagrama de caja, pero en este caso tiene la función de distribución en lugar de la propia caja

# %%
plt.figure(figsize=(20,5))
sns.violinplot(titanic_df["Fare"],color = 'deeppink');

# %%
plt.figure(figsize=(20,5))
sns.violinplot(titanic_df["Fare"],color = 'deeppink', inner='stick');

# %% [markdown]
# ### 1.2 Variables cualitativas
# Para representar una variable categórica tendremos que ver su frecuencia de valores
#
# En este caso vamos a ver qué tipo de embarque ha sido el más frecuente.
#
# [Documentacion](https://seaborn.pydata.org/generated/seaborn.countplot.html)

# %%
plt.figure(figsize=(7,5))
sns.countplot(titanic_df["Embarked"])
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %% [markdown]
# #### Lollipop
#
# ¿Cuáles han sido los productos más pedidos?
#
# [Documentación](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.hlines.html)

# %%
market_df['Product line'].value_counts(ascending=True)
# Out:
# Health and beauty         152
# Home and lifestyle        160
# Sports and travel         166
# Electronic accessories    170
# Food and beverages        174
# Fashion accessories       178
# Name: Product line, dtype: int64

# %%
conteo = market_df['Product line'].value_counts(ascending=True)
plt.figure(figsize=(10,5))
plt.hlines(y=conteo.index,
           xmin=140,
          xmax = conteo,
          color='skyblue')
plt.plot(conteo, conteo.index, 'o');

# %% [markdown]
# #### Donut chart/Pie chart
#
# [Documentación](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.pie.html)

# %%
#import matplotlib.pyplot as plt
 
# create data
data = titanic_df["Embarked"].value_counts()
 
# Create a circle for the center of the plot
# 0.7 es el valore del radio
my_circle = plt.Circle((0,0), 0.7, color='white')

plt.figure(figsize=(8,8))
plt.pie(data.values,
        labels=data.index,
        autopct='%1.2f%%')
p=plt.gcf()
#Si no se añade el círculo tendríamos un gráfico de tarta
p.gca().add_artist(my_circle)
#plt.show()

# %%
# pie chart
#import matplotlib.pyplot as plt
 
# create data
data = titanic_df["Embarked"].value_counts()
 
# Create a circle for the center of the plot
# 0.7 es el valore del radio
my_circle = plt.Circle((0,0), 0.7, color='white')

plt.figure(figsize=(8,8))
plt.pie(data.values,
        labels=data.index,
        autopct='%1.2f%%')
p=plt.gcf()
#Si no se añade el círculo tendríamos un gráfico de tarta
#p.gca().add_artist(my_circle)
#plt.show()

# %% [markdown]
# ## 2. Análisis Bivariante
# ### 2.1 Comparativa de variables cuantitativas (2-4 variables)
# #### Boxplot
#
# En este ejemplo veremos cómo de diferentes son las distribuciones de las 4 características que definen a una flor.
#
# [Boxlot](https://seaborn.pydata.org/generated/seaborn.boxplot.html)

# %%
iris_df.columns.values[:4]
# Out:
# array(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'], dtype=object)

# %%
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data=iris_df[iris_df.columns.values[:4]]);

# %% [markdown]
# El boxplot está bien, pero hay algo de información que se nos escapa.<br>
# El enjambre nos permitirá ver el número de observaciones que tenemos dentro de cada área del bloxpot

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data=iris_df[iris_df.columns.values[:4]])
sns.swarmplot(data=iris_df[iris_df.columns.values[:4]], color='black');

# %% [markdown]
# #### Diagramas de densidad
#
# Otra manera de ver cómo se distribuyen las características de las flores.
#
# [Documentación](https://seaborn.pydata.org/generated/seaborn.kdeplot.html)

# %%
plt.figure(figsize=(12,8))
sns.kdeplot(data=iris_df[iris_df.columns.values[:4]], shade=True);

# %% [markdown]
# #### Histogramas
#
# [Documentación](https://seaborn.pydata.org/generated/seaborn.distplot.html)

# %%
plt.figure(figsize=(12,8))
sns.distplot(iris_df["sepal length (cm)"], color='skyblue', label='Sepal Length')
sns.distplot(iris_df["sepal width (cm)"], color='red', label='Sepal Width')
plt.legend();

# %%
f, axes = plt.subplots(2, 2, figsize=(15,10), sharex=True)
sns.distplot(iris_df["sepal length (cm)"] , color="skyblue", ax=axes[0, 0])
sns.distplot(iris_df["sepal width (cm)"] , color="olive", ax=axes[0, 1])
sns.distplot(iris_df["petal length (cm)"] , color="gold", ax=axes[1, 0])
sns.distplot(iris_df["petal width (cm)"] , color="teal", ax=axes[1, 1]);

# %% [markdown]
# #### Scatter plot
#
# En este ejemplo se ve claramente cómo estas dos variables sirven para distinguir las setosas de los otros tipos de flores
#
# [Documentación](https://seaborn.pydata.org/generated/seaborn.scatterplot.html)

# %%
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x = iris_df["sepal length (cm)"],
                y = iris_df["sepal width (cm)"],
               s = 100,
               hue = iris_df["target"] );
# con hue se le indica que se de un calor al punto según el valor en el campo target
# si no lo usáramos saldrían todos los puntos negros

# %% [markdown]
# [Documentación dataset](https://scikit-learn.org/stable/datasets/index.html#boston-dataset)
#
# [Documentación jointplot](https://seaborn.pydata.org/generated/seaborn.jointplot.html)
#
# % poblacion con poco poder adquisitivo vs media de habitaciones por vivienda

# %%
from sklearn.datasets import fetch_california_housing
dataset = fetch_california_housing()
X_full, y_full = dataset.data, dataset.target
# X_ (mayuscula) es porque es una matriz con varias columnas
# y_ (minuscula) es porque es un vector de una columna
feature_names = dataset.feature_names

california_df = pd.DataFrame(data = X_full ,  columns = feature_names)
california_df['Price'] = y_full

# %%
california_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Prices
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422

# %%
# logaritmo y exponencial son operaciones contrarias 
# Aplicando logaritmos hacemos un número muy grande mas pequeño 
sns.jointplot(x = np.log10(california_df['Population']),
             y = california_df['AveRooms'],
            color='green');

# %% [markdown]
# **jointplot** dibuja una nube de puntos y además la distribución de cada variable

# %%
sns.jointplot(x = np.log10(california_df['Population']),
             y = np.log10(california_df['AveRooms']),
              kind='hex',
            color='green');

# %%
sns.jointplot(x = np.log10(california_df['Population']),
             y = np.log10(california_df['AveRooms']),
              kind='kde',
            color='green');

# %% [markdown]
# ### 2.2 Comparativa de múltiples numéricas

# %% [markdown]
# #### Heatmaps
#
# Los heatmaps son perfectos para representar una matriz de correlación
#
# [Documentación heatmap](https://seaborn.pydata.org/generated/seaborn.heatmap.html)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(california_df.corr(),
           vmin = -1,
           vmax = 1,
           cmap = sns.diverging_palette(145, 280, s=85, l=25, n=7),
           annot = True,
           square = True,
           linewidths = .5);

#con annot=True  indicamos que queremos ver el valor dentro de la caja

# %% [markdown]
# También nos permite comparar una variable numérica vs dos variables categóricas. Por ejemplo la cantidad de suicidios desagregado por edades y paises.
#
# Se recomienda que las dos variables categóricas tengan pocos casos, porque sino no se va a ver bien el heatmap.

# %%
market_df['Product line']
# Out:
# 0           Health and beauty
# 1      Electronic accessories
# 2          Home and lifestyle
# 3           Health and beauty
# 4           Sports and travel
#                 ...
# 995         Health and beauty
# 996        Home and lifestyle
# 997        Food and beverages
# 998        Home and lifestyle
# 999       Fashion accessories
# Name: Product line, Length: 1000, dtype: object

# %%
data = market_df.groupby(['Product line', 'Payment']).sum()['Quantity'].unstack()
data = data.loc[['Electronic accesories', 'Fashion accesories', 'Food and beverages']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4984/3582813317.py in <module>
#       1 data = market_df.groupby(['Product line', 'Payment']).sum()['Quantity'].unstack()
# ----> 2 data = data.loc[['Electronic accesories', 'Fashion accesories', 'Food and beverages']]
#
# ~\.conda\envs\TheBridgeBootcamp\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~\.conda\envs\TheBridgeBootcamp\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1151                     raise ValueError("Cannot index with multidimensional key")
#    1152
# -> 1153                 return self._getitem_iterable(key, axis=axis)
#    1154
#    1155             # nested tuple slicing
#
# ~\.conda\envs\TheBridgeBootcamp\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1091
#    1092         # A collection of keys
# -> 1093         keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1094         return self.obj._reindex_with_indexers(
#    1095             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# ~\.conda\envs\TheBridgeBootcamp\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~\.conda\envs\TheBridgeBootcamp\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 1377             raise KeyError(f"{not_found} not in index")
#    1378
#    1379
#
# KeyError: "['Electronic accesories', 'Fashion accesories'] not in index"

# %%
data.head()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data, square=True, linewidth=0.3)

# %% [markdown]
# #### Correlograma
#
# [Documentación Pairplot](https://seaborn.pydata.org/generated/seaborn.pairplot.html)
#
# Interesante gráfica para ver en un dataset qué variables presentan correlación lineal, así como sus distribuciones. NO realices esta gráfica con muchas variables porque no verá bien. Hazlo por partes.
#
# Regresión lineal : cual es la recta que mejor se adapta a los puntos, que en promedio tengan la misma distancia a la recta

# %%
sns.pairplot(iris_df, kind='reg');

# %%
sns.pairplot(iris_df, kind='scatter', hue='target', plot_kws=dict(s=80,edgecolor='white',linewidth=2));

# %%
sns.pairplot(iris_df, kind='scatter', hue='target',diag_kind='hist');

# %% [markdown]
# ### 2.3 Comparativa de dos variables cualitativas
# #### Tabla
#
# [Documentacion](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.crosstab.html)
#
# Lo más sencillo, una tabla con la frecuencia de valores. Esto es factible cuando los elementos únicos por categoría no son muchos.

# %%
pd.crosstab(titanic_df['Embarked'],titanic_df['Fare'])
# Out:
# Fare      6.7500    6.9750    7.0500    7.1417    7.2250    7.2292    \
# Embarked
# C                0         0         0         0         2         3
# Q                1         0         0         0         0         0
# S                0         1         1         1         0         0
#
# Fare      7.2500    7.3125    7.6500    7.7500    ...  71.2833   73.5000   \
# Embarked                                          ...
# C                0         0         0         0  ...         1         0
# Q                0         0         0         4  ...         0         0
# S                2         1         2         1  ...         0         2
#
# Fare      76.7292   77.2875   79.2000   82.1708   83.4750   146.5208  \
# Embarked
# C                1         0         1         1         0         1
# Q                0         0         0         0         0         0
# S                0         2         0         0         1         0
#
# Fare      247.5208  263.0000
# Embarked
# C                1         0
# Q                0         0
# S                0         2
#
# [3 rows x 92 columns]

# %% [markdown]
# #### Diagrama de barras
#
# [Documentacion](https://seaborn.pydata.org/generated/seaborn.catplot.html)
#
# En un diagrama de barras también se entiende la representación de dos variables cualitativas

# %%
sns.catplot(y='Embarked', hue='Fare', orientation='horizontal', kind='count', data=titanic_df);

# %% [markdown]
# Otra manera de visualizar dos o más variables categóricas

# %%
plt.figure(figsize=(30,10))
sns.catplot(x="Survived",
            col="Embarked",
            col_wrap=4,
           data=titanic_df,
           kind='count');

# %%
titanic_df.groupby(["Embarked","Survived"]).size()
#Al haber hecho el group by los indices son Embarked y survived
# Out:
# Embarked  Survived
# C         0           20
#           1           12
# Q         0            6
#           1            7
# S         0           76
#           1           34
# dtype: int64

# %%
titanic_df.groupby(["Embarked","Survived"]).size().reset_index()
#Al hacer reset index los indices pasan a ser valor de columna y a la serie de size que no tenía nombre se le asigna 0 como nombre
# Out:
#   Embarked  Survived   0
# 0        C         0  20
# 1        C         1  12
# 2        Q         0   6
# 3        Q         1   7
# 4        S         0  76
# 5        S         1  34

# %%
titanic_df.groupby(["Embarked","Survived"]).size().reset_index().pivot(columns="Embarked", index="Survived", values=0)
#Con values=0 indicamos que coja la columna llamada 0
# Out:
# Embarked   C  Q   S
# Survived
# 0         20  6  76
# 1         12  7  34

# %%
df_plot = titanic_df.groupby(["Embarked","Survived"]).size().reset_index().pivot(columns="Embarked", index="Survived", values=0)
df_plot.plot(kind='bar', stacked=True);

# %% [markdown]
# ### 2.4 Cualitativa vs cuantitativa
# #### Time series
#
# [Documentacion](https://seaborn.pydata.org/generated/seaborn.lineplot.html)
#
# Las series temporales tienen la particularidad de que son datos ordenados

# %%
eventos_df=pd.read_csv('./data/holidays_events.csv')
eventos_df.head()
# Out:
#          date     type    locale locale_name                    description  \
# 0  2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 1  2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2  2012-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 3  2012-04-14  Holiday     Local    Libertad      Cantonizacion de Libertad
# 4  2012-04-21  Holiday     Local    Riobamba      Cantonizacion de Riobamba
#
#    transferred
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
eventos_df['type'].unique()
# Out:
# array(['Holiday', 'Transfer', 'Additional', 'Bridge', 'Work Day', 'Event'],
#       dtype=object)

# %%
eventos_df = eventos_df.loc[eventos_df['type'].isin(['Holiday', 'Event', 'Bridge']),:]
eventos_df['year']=eventos_df.loc[:, 'date'].str[:4].astype(int)
eventos_df = eventos_df.groupby(['locale','year']).sum()
eventos_df.reset_index(inplace=True)

# %%
eventos_df.head()
# Out:
#   locale  year  transferred
# 0  Local  2012            0
# 1  Local  2013            0
# 2  Local  2014            0
# 3  Local  2015            0
# 4  Local  2016            1

# %%
plt.figure(figsize=(15,10))
sns.lineplot(data= eventos_df,
            x='year',
            y = 'transferred',
            hue = 'locale',
            linewidth = 3);

# %% [markdown]
# #### Treemap
# Un treemap es una opción muy interesante para mostrar una variable numérica vs una categórica

# %%
# !pip install squarify
# Out:
# Collecting squarify
#   Downloading squarify-0.4.3-py3-none-any.whl (4.3 kB)
# Installing collected packages: squarify
# Successfully installed squarify-0.4.3

# %%
eventos_df.groupby("locale").sum()['transferred'].sort_values(ascending=False)
# Out:
# locale
# National    8
# Local       4
# Regional    0
# Name: transferred, dtype: int64

# %%
import squarify

eventos_df=pd.read_csv('./data/holidays_events.csv')
eventos_df = eventos_df.loc[eventos_df['type'].isin(['Holiday', 'Event', 'Bridge']),:]

data=eventos_df.groupby("locale_name").sum()['transferred'].sort_values(ascending=False)[:5]

plt.figure(figsize=(15,10))
squarify.plot(sizes=data.values, label=data.index);

# %% [markdown]
# Con este catplot obtenemos la dispersión de la variable Age, por cada grupo de la categoría.

# %%
sns.catplot(x="Survived", y="Age", hue="Embarked",data=titanic_df);

# %% [markdown]
# El equivalente con un diagrama de caja sería el siguiente

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x="Survived", y="Age", hue="Embarked",data=titanic_df);

# %%
plt.figure(figsize=(20,10))
sns.catplot(x="Survived", y="Age", hue="Embarked",kind='violin', data=titanic_df);

# %%
plt.figure(figsize=(20,10))
sns.catplot(x="Embarked", y="Age", hue="Survived",kind='violin',split=True, data=titanic_df);

# %%
import seaborn as sns
eventos_df = pd.read_csv('./data/holidays_events.csv')
eventos_df = eventos_df.loc[eventos_df.type.isin(['Holiday', 'Event', 'Bridge']),:]
eventos_df['year'] = eventos_df['date'].str[:4].astype(int)
eventos_df = eventos_df.loc[eventos_df.year.isin([2015, 2016, 2017]),:]

chart = sns.catplot(x = 'type',
                   y = 'transferred',
                   hue = 'locale',
                   col = 'year',
                   data  = eventos_df)

chart.set_xticklabels(rotation = 45);

# %%
sns.catplot(x="Fare",
            y="Embarked",
            hue="Sex",
            kind="violin",
            bw=.1,
            height=8,
            aspect=.8,
            data=titanic_df);

# %%
plt.figure(figsize=(10,5))

# %%
df1 = eventos_df.groupby('year').sum()['transferred']
df2 = eventos_df[eventos_df['locale'] == 'Local'].groupby('year').sum()['transferred']
df1 = df1[df1.index.isin(df2.index)]

df_tot = pd.DataFrame({"Tot_transferred": df1, "Locale": df2}).sort_values("Tot_transferred", ascending=False)[:20]
df_tot.reset_index(level=0, inplace=True)

# %%
df_tot
# Out:
#    year  Tot_transferred  Locale
# 0  2017                6       3
# 1  2016                3       1
# 2  2015                0       0

# %%
eventos_df.head()
# Out:
#            date     type    locale locale_name                description  \
# 159  2015-01-01  Holiday  National     Ecuador         Primer dia del ano
# 160  2015-01-02   Bridge  National     Ecuador  Puente Primer dia del ano
# 162  2015-02-16  Holiday  National     Ecuador                   Carnaval
# 163  2015-02-17  Holiday  National     Ecuador                   Carnaval
# 164  2015-03-02  Holiday     Local       Manta         Fundacion de Manta
#
#      transferred  year
# 159        False  2015
# 160        False  2015
# 162        False  2015
# 163        False  2015
# 164        False  2015

# %%
# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 15))

sns.set_color_codes("pastel")
sns.barplot(x="year", y="Tot_transferred", data=df_tot,
            label="Total", color="b")

sns.set_color_codes("muted")
sns.barplot(x="year", y="Locale", data=df_tot,
            label="Locale", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
sns.despine(left=True, bottom=True)

# %% [markdown]
# #### Bubble chart

# %%
#eventos_df2 = eventos_df[eventos_df['year'] == 2017]
eventos_df = pd.read_csv('./data/holidays_events.csv')
eventos_df['year'] = eventos_df['date'].str[:4].astype(int)
eventos_df2 = eventos_df

sns.relplot(data=eventos_df2,
            x="locale",
            y="transferred",
            hue="year", size="type",
            sizes=(4, 300),
            alpha=.05, palette="muted",
            height=6);

# %% [markdown]
# ####
