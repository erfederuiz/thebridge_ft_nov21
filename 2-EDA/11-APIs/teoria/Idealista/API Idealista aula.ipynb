# %%
import argparse
import json
import os
import time
import requests
from requests.auth import HTTPBasicAuth

idealista_url = "https://api.idealista.com/oauth/token"
payload = {"grant_type": "client_credentials"}
r = requests.post(idealista_url,
                  auth=HTTPBasicAuth("9imfkl9ugl3ofiv9b95i7am1w98yzpu7", "8nZfatljCytZ"),
                  data=payload)
print(r.text)
token_response = json.loads(r.text)
token_value = token_response["access_token"]
print("Token: " + token_value)

country = 'es'
center = '40.42938099999995,-3.7097526269835726'
numPage = '1'
distance = '1000'
propertyType = 'homes'
operation = 'rent'

api_url = "http://api.idealista.com/3.5/es/search?center="+center+"&country="+country+"&distance="+distance+"&propertyType="+propertyType+"&operation="+operation
print(api_url)

headers = {"Authorization": "Bearer " + token_value}
r = requests.post(api_url, headers=headers)
#print(r.text)
search_json = r.text
search_response = json.loads(search_json)
search_pretty = json.dumps(search_response, indent=4, sort_keys=True)
print(search_pretty)
# Out:
# {"access_token":"eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzY29wZSI6WyJyZWFkIl0sImV4cCI6MTY0MDA4NDY4MSwiYXV0aG9yaXRpZXMiOlsiUk9MRV9QVUJMSUMiXSwianRpIjoiNmI2NzlmNDQtNGVlOS00MTVmLTgwNmYtNTJiNzUzNWMxZWNiIiwiY2xpZW50X2lkIjoiOWltZmtsOXVnbDNvZml2OWI5NWk3YW0xdzk4eXpwdTcifQ.aIEz3I0q_GZsiHUUVxjfiYhdoQchOlDsQRi4N7b1xWY","token_type":"bearer","expires_in":43199,"scope":"read","jti":"6b679f44-4ee9-415f-806f-52b7535c1ecb"}
# Token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzY29wZSI6WyJyZWFkIl0sImV4cCI6MTY0MDA4NDY4MSwiYXV0aG9yaXRpZXMiOlsiUk9MRV9QVUJMSUMiXSwianRpIjoiNmI2NzlmNDQtNGVlOS00MTVmLTgwNmYtNTJiNzUzNWMxZWNiIiwiY2xpZW50X2lkIjoiOWltZmtsOXVnbDNvZml2OWI5NWk3YW0xdzk4eXpwdTcifQ.aIEz3I0q_GZsiHUUVxjfiYhdoQchOlDsQRi4N7b1xWY
# http://api.idealista.com/3.5/es/search?center=40.42938099999995,-3.7097526269835726&country=es&distance=1000&propertyType=homes&operation=rent
# {
#     "actualPage": 1,
#     "elementList": [
#         {
#             "address": "Plaza de Carlos Cambronero",
#             "bathrooms": 1,
#             "country": "es",
#             "description": "Top Properties presenta duplex ubicado en el coraz\u00f3n de Malasa\u00f1a, Plaza de Carlos Cambronero. Se trata de un semi-s\u00f3tano interior sin ascensor. El inmueble dispone de 66 m2 de los cuales 48 m2 son \u00fatiles. El inmueble dispone de acogedor sal\u00f3n/comedor con ventanales los cuales aportan iluminaci\u00f3n. Cocina, completamente amueblada y equipada, 1 habitaci\u00f3n en suite, cuarto de ba\u00f1o con plato de ducha. Una segunda habitaci\u00f3n, con ventana a un patio. El inmueble se encuentra ubicado en una zona inmejorable, cerca de parques, colegios, farmacias. Mejor ver! Top Properties es una compa\u00f1\u00eda de intermediaci\u00f3n inmobiliaria, comenzamos como agentes inmobiliarios con conocidas compa\u00f1\u00edas, pero despu\u00e9s de adquirir conocimiento en Espa\u00f1a y fuera de ella, decidimos independizarnos para tratar de cambiar la idea de lo que es una inmobiliaria convencional. Nuestros servicios var\u00edan desde la compra o venta de tu casa, comercio o herencia como igual el alquiler de inmuebles. Ofrecemos servicios de financiaci\u00f3n, conseguimos la hipoteca que necesita a su medida. Sin complicaciones, sin l\u00edmites. Para asegurar una mayor tranquilidad, somos agentes aseguradores, lo cual podemos siempre ofrecer a nuestros clientes un amplio abanico de servicios con la finalidad de consolidar una calma con seguros de hogar, vida, impago y muchos m\u00e1s. Tenemos un trato personal con todos nuestros clientes, es decir tu trato comienza con un asesor, el cual estar\u00e1 contigo en todo proceso de la operaci\u00f3n de tu inmueble.",
#             "detailedType": {
#                 "subTypology": "duplex",
#                 "typology": "flat"
#             },
#             "distance": "944",
#             "district": "Centro",
#             "exterior": true,
#             "externalReference": "PA-CML",
#             "floor": "ss",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": false,
#             "hasPlan": false,
#             "hasStaging": false,
#             "hasVideo": false,
#             "latitude": 40.4232935,
#             "longitude": -3.7019714,
#             "municipality": "Madrid",
#             "neighborhood": "Malasa\u00f1a-Universidad",
#             "newDevelopment": false,
#             "numPhotos": 18,
#             "operation": "rent",
#             "price": 850.0,
#             "priceByArea": 13.0,
#             "propertyCode": "96251265",
#             "propertyType": "duplex",
#             "province": "Madrid",
#             "rooms": 2,
#             "showAddress": false,
#             "size": 66.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Malasa\u00f1a-Universidad, Madrid",
#                 "title": "D\u00faplex en Plaza de Carlos Cambronero"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/78/90/f9/941709392.jpg",
#             "topNewDevelopment": false,
#             "url": "https://www.idealista.com/inmueble/96251265/"
#         },
#         {
#             "address": "Calle del Marqu\u00e9s de Santa Ana",
#             "bathrooms": 1,
#             "country": "es",
#             "description": "Alquiler de piso en barrio de Malasa\u00f1a, el inmueble se encuentra amueblado, tiene dos habitaciones con armarios empotrados, sal\u00f3n con sof\u00e1 mesas y sillas, cocina equipada y lavadora, se encuentra para entrar a vivir. El piso es exterior con dos balcones a la calle, zona tranquila y muy bien comunicada con restaurantes, comercios.  Interesados dejar tel\u00e9fono y nos pondremos en contacto lo antes posible.",
#             "detailedType": {
#                 "typology": "flat"
#             },
#             "distance": "593",
#             "district": "Centro",
#             "exterior": true,
#             "floor": "2",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": false,
#             "hasPlan": false,
#             "hasStaging": false,
#             "hasVideo": false,
#             "latitude": 40.4265419,
#             "longitude": -3.7038214,
#             "municipality": "Madrid",
#             "neighborhood": "Malasa\u00f1a-Universidad",
#             "newDevelopment": false,
#             "numPhotos": 7,
#             "operation": "rent",
#             "price": 800.0,
#             "priceByArea": 18.0,
#             "propertyCode": "96251194",
#             "propertyType": "flat",
#             "province": "Madrid",
#             "rooms": 2,
#             "showAddress": false,
#             "size": 45.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Malasa\u00f1a-Universidad, Madrid",
#                 "title": "Piso en Calle del Marqu\u00e9s de Santa Ana"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/d7/44/41/941708071.jpg",
#             "topNewDevelopment": false,
#             "url": "https://www.idealista.com/inmueble/96251194/"
#         },
#         {
#             "address": "Corredera Baja de San Pablo",
#             "bathrooms": 1,
#             "country": "es",
#             "description": "Home Select presenta este estupendo apartamento exterior, que se alquila completamente amueblado. Ubicaci\u00f3n Este apartamento tiene una magn\u00edfica ubicaci\u00f3n en el centro de la capital, en el barrio de Malasa\u00f1a, uno de los m\u00e1s castizos de Madrid y que ha tenido gran crecimiento en los \u00faltimos a\u00f1os. Se encuentra en una calle muy de moda dentro de esta zona, con multitud de servicios a su alrededor: tiendas, boutiques, restaurantes y bares para todos los gustos, desde los m\u00e1s tradicionales a los m\u00e1s modernos. La propiedad est\u00e1 situada muy cerca de lugares emblem\u00e1ticos, como la Iglesia de San Antonio o el Teatro Lara, ubicados a pocos pasos. Adem\u00e1s, est\u00e1 a poca distancia de calles principales como la Gran V\u00eda, por lo que las comunicaciones de transporte p\u00fablico y privado con el resto de la ciudad son estupendas. Descripci\u00f3n La distribuci\u00f3n est\u00e1 pensada para aprovechar cada espacio. La estancia principal es el sal\u00f3n, con tres balcones a la calle que aportan una gran luminosidad a toda la zona. Dispone de una estupenda zona de estar y una chimenea decorativa situada entre dos de los balcones. A un lado del sal\u00f3n tenemos una zona de comedor, y una cocina amueblada y con todos los electrodom\u00e9sticos. El ba\u00f1o est\u00e1 situado en la parte central. La gran altura de techos ha permitido instalar una escalera, en un lateral del sal\u00f3n, que nos lleva a una segunda altura donde encontramos el dormitorio, con cama doble.  Contacto Para consultar m\u00e1s informaci\u00f3n, p\u00f3ngase en contacto con nosotros. H o m e s e l e c t. c o m Estamos en contacto!",
#             "detailedType": {
#                 "typology": "flat"
#             },
#             "distance": "954",
#             "district": "Centro",
#             "exterior": true,
#             "externalReference": "CE-67.",
#             "floor": "1",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": false,
#             "hasStaging": false,
#             "hasVideo": false,
#             "latitude": 40.4213353,
#             "longitude": -3.7058086,
#             "municipality": "Madrid",
#             "neighborhood": "Malasa\u00f1a-Universidad",
#             "newDevelopment": false,
#             "numPhotos": 21,
#             "operation": "rent",
#             "price": 1200.0,
#             "priceByArea": 30.0,
#             "propertyCode": "96251099",
#             "propertyType": "flat",
#             "province": "Madrid",
#             "rooms": 1,
#             "showAddress": false,
#             "size": 40.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Malasa\u00f1a-Universidad, Madrid",
#                 "title": "Piso en Corredera Baja de San Pablo"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/55/06/b7/941705297.jpg",
#             "topNewDevelopment": false,
#             "url": "https://www.idealista.com/inmueble/96251099/"
#         },
#         {
#             "address": "barrio Malasa\u00f1a-Universidad",
#             "bathrooms": 1,
#             "country": "es",
#             "description": "Estupendo \u00e1tico amueblado en el coraz\u00f3n de Malasa\u00f1a. Reci\u00e9n reformado y muy luminoso, dispone de sal\u00f3n con cocina integrada y ba\u00f1o totalmente equipados, dos habitaciones, una con cama matrimonial y otra con cama mas peque\u00f1a, abuhardillado, suelos de tarima, ventanas climalit, aire acondicionado y radiadores el\u00e9ctricos. A cinco minutos andando de Metros Noviciado y Bilbao, pr\u00f3ximo a parada de autobuses y servicios. Para largas y cortas estancias, si es minimo un a\u00f1o 990\u20ac, por 6 meses 1100\u20ac y por 3 meses 1200\u20ac. \"Somos una consultora inmobiliaria de nueva generaci\u00f3n formada por un equipo profesional y din\u00e1mico, con reconocido prestigio y experiencia dentro del sector inmobiliario. Ofertamos servicios a medida de las necesidades de cada cliente, garantizando un resultado adecuado a sus exigencias y necesidades particulares\" -ASESORAMIENTO PERSONALIZADO Y GRATUITO EN LA B\u00daSQUEDA DE SU INMUEBLE. \". \". \". \". \". \". \". \". \". \". \". \". \". \". \".",
#             "detailedType": {
#                 "subTypology": "penthouse",
#                 "typology": "flat"
#             },
#             "distance": "694",
#             "district": "Centro",
#             "exterior": true,
#             "externalReference": "F-ES-26",
#             "floor": "4",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": false,
#             "hasPlan": false,
#             "hasStaging": false,
#             "hasVideo": true,
#             "latitude": 40.4256931,
#             "longitude": -3.7031246,
#             "municipality": "Madrid",
#             "neighborhood": "Malasa\u00f1a-Universidad",
#             "newDevelopment": false,
#             "numPhotos": 23,
#             "operation": "rent",
#             "price": 990.0,
#             "priceByArea": 20.0,
#             "propertyCode": "96251037",
#             "propertyType": "penthouse",
#             "province": "Madrid",
#             "rooms": 2,
#             "showAddress": false,
#             "size": 50.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Malasa\u00f1a-Universidad, Madrid",
#                 "title": "\u00c1tico"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/b7/c6/d6/941703883.jpg",
#             "topNewDevelopment": false,
#             "url": "https://www.idealista.com/inmueble/96251037/"
#         },
#         {
#             "address": "barrio Arapiles",
#             "bathrooms": 1,
#             "country": "es",
#             "description": "\u00a1SERVICHECK ALQUILA PISO EN MADRID! Para m\u00e1s informaci\u00f3n y visitas, preguntar por Pablo Mart\u00edn al 635_212_807 (Tambi\u00e9n se atiende por WhatsApp) Este piso de 80 mts en la zona de Chamber\u00ed se distribuye de la siguiente manera: - Dos habitaciones con armarios empotrados y ventanas. - Un ba\u00f1o con ba\u00f1era. - Un salon amplio y luminoso. - Una cocina independiente completamente equipada. Para m\u00e1s informaci\u00f3n y visitas, preguntar por Pablo Mart\u00edn al 635_212_807 (Tambi\u00e9n se atiende por WhatsApp).",
#             "detailedType": {
#                 "typology": "flat"
#             },
#             "distance": "772",
#             "district": "Chamber\u00ed",
#             "exterior": true,
#             "externalReference": "pablo/murillo",
#             "floor": "3",
#             "has360": false,
#             "has3DTour": true,
#             "hasLift": false,
#             "hasPlan": false,
#             "hasStaging": false,
#             "hasVideo": false,
#             "latitude": 40.4339545,
#             "longitude": -3.7028841,
#             "municipality": "Madrid",
#             "neighborhood": "Arapiles",
#             "newDevelopment": false,
#             "numPhotos": 14,
#             "operation": "rent",
#             "price": 1050.0,
#             "priceByArea": 13.0,
#             "propertyCode": "96188043",
#             "propertyType": "flat",
#             "province": "Madrid",
#             "rooms": 2,
#             "showAddress": false,
#             "size": 80.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Arapiles, Madrid",
#                 "title": "Piso"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/e4/89/ba/939751590.jpg",
#             "topNewDevelopment": false,
#             "url": "https://www.idealista.com/inmueble/96188043/"
#         },
#         {
#             "address": "Calle de Fernando el Cat\u00f3lico",
#             "bathrooms": 1,
#             "country": "es",
#             "description": "URBANA 65 Alquila magn\u00edfico APARTAMENTO EXTERIOR, reformado y amueblado en la zona de Arapiles, Barrio de Chamber\u00ed. Consta de un dormitorio con cama doble, armario y maletero, sal\u00f3n comedor con cocina americana equipada con electrodom\u00e9sticos y ba\u00f1o completo con plato de ducha.  Dispone de calefacci\u00f3n individual por gas natural, suelos de tarima y ascensor. Estupenda ubicaci\u00f3n, con todo tipo de servicios a su alrededor; bares, lugares de ocio, comercios, transporte, servicios sanitarios, acad\u00e9micos y a un paso de la plaza de Quevedo y la calle de Fuencarral. Ideal trabajadores, Mejor ver!",
#             "detailedType": {
#                 "typology": "flat"
#             },
#             "distance": "597",
#             "district": "Chamber\u00ed",
#             "exterior": true,
#             "externalReference": "A-1299",
#             "floor": "bj",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": false,
#             "hasStaging": false,
#             "hasVideo": false,
#             "latitude": 40.4346027,
#             "longitude": -3.7114101,
#             "municipality": "Madrid",
#             "neighborhood": "Arapiles",
#             "newDevelopment": false,
#             "numPhotos": 12,
#             "operation": "rent",
#             "price": 720.0,
#             "priceByArea": 19.0,
#             "propertyCode": "96250292",
#             "propertyType": "flat",
#             "province": "Madrid",
#             "rooms": 1,
#             "showAddress": false,
#             "size": 37.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Arapiles, Madrid",
#                 "title": "Piso en Calle de Fernando el Cat\u00f3lico"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/15/07/4b/941683341.jpg",
#             "topNewDevelopment": false,
#             "url": "https://www.idealista.com/inmueble/96250292/"
#         },
#         {
#             "address": "Calle de Vallehermoso",
#             "bathrooms": 1,
#             "country": "es",
#             "description": "-CHAMBER\u00cd- Piso reformado de 55m\u00b2, interior, sin amueblar y para entrar a vivir. La vivienda consta de sal\u00f3n, dos dormitorios con armarios empotrados, un cuarto de ba\u00f1o con plato de ducha y cocina americana, amueblada y equipada con vitrocer\u00e1mica, campana, horno, lavavajillas y frigor\u00edfico. Puerta blindada, ventanas de doble acristalamiento, suelos de gres y pintura lisa. Calefacci\u00f3n central incluida y agua caliente central individual. La finca dispone de ascensor y portero. Mascotas a consultar. Certificado energ\u00e9tico en tr\u00e1mite. El inmueble se encuentra al lado de la parada de Metro Quevedo. Rodeado de todo tipo de servicios, comercios y zonas de ocio. Gastos de comunidad incluidos en el precio. SIN COMISI\u00d3N DE AGENCIA.",
#             "detailedType": {
#                 "typology": "flat"
#             },
#             "distance": "321",
#             "district": "Chamber\u00ed",
#             "exterior": false,
#             "externalReference": "1727",
#             "floor": "bj",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": false,
#             "hasStaging": false,
#             "hasVideo": false,
#             "latitude": 40.4311239,
#             "longitude": -3.7067173,
#             "municipality": "Madrid",
#             "neighborhood": "Arapiles",
#             "newDevelopment": false,
#             "numPhotos": 21,
#             "operation": "rent",
#             "price": 1000.0,
#             "priceByArea": 18.0,
#             "propertyCode": "96250242",
#             "propertyType": "flat",
#             "province": "Madrid",
#             "rooms": 2,
#             "showAddress": false,
#             "size": 55.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Arapiles, Madrid",
#                 "title": "Piso en Calle de Vallehermoso"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/a6/5d/62/941678197.jpg",
#             "topNewDevelopment": false,
#             "url": "https://www.idealista.com/inmueble/96250242/"
#         },
#         {
#             "address": "barrio Chueca-Justicia",
#             "bathrooms": 3,
#             "country": "es",
#             "description": "Piso en alquiler en Justicia Vivienda de 110\u202fm\u00b2 en una de las calles m\u00e1s representativas del barrio de Justicia, cercana al Mercado Barcel\u00f3 y a la Glorieta de Alonso Mart\u00ednez. Consta de 2 amplias habitaciones en suite, y cocina con lavadero, integrada en el sal\u00f3n. Reci\u00e9n reformada, con las m\u00e1s altas calidades en todas las estancias y totalmente amueblada. La iluminaci\u00f3n es regulable, con posibilidad de controlar la iluminaci\u00f3n y climatizaci\u00f3n. La zona tiene muy buena comunicaci\u00f3n tanto en transporte privado, como en transporte p\u00fablico, ya que se encuentra muy cerca de Sagasta. A 20 minutos del Aeropuerto y a 10 minutos de la estaci\u00f3n de Atocha. Desde la entrada se accede al sal\u00f3n con cocina abierta y zona de comedor diferenciada. La cocina est\u00e1 equipada con lavadora-secadora, lavaplatos, horno, microondas y peque\u00f1o electrodom\u00e9stico adem\u00e1s de una c\u00f3moda zona de lavadero. La zona de estar cuenta con un amplio sof\u00e1 en forma de L. El primer dormitorio con cama doble cuenta con armario empotrado y ba\u00f1o en suite. El segundo dormitorio, tambi\u00e9n con ba\u00f1o en suite con ducha y ba\u00f1era. La habitaci\u00f3n principal cuenta con cuarto de ba\u00f1o en suite. Igualmente tiene armarios empotrados. Ambos dormitorios dan al patio del edificio siendo muy silenciosos para el descanso. La vivienda cuenta con calefacci\u00f3n individual y aire acondicionado por conductos mediante bomba fr\u00edo-calor. La casa se caracteriza por su luz natural y su exquisita decoraci\u00f3n, habiendo sido cuidada hasta el m\u00e1s m\u00ednimo detalle.",
#             "detailedType": {
#                 "typology": "flat"
#             },
#             "distance": "999",
#             "district": "Centro",
#             "exterior": false,
#             "externalReference": "AM2112006",
#             "floor": "4",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": false,
#             "hasStaging": false,
#             "hasVideo": true,
#             "latitude": 40.4257521,
#             "longitude": -3.6989524,
#             "municipality": "Madrid",
#             "neighborhood": "Chueca-Justicia",
#             "newDevelopment": false,
#             "numPhotos": 32,
#             "operation": "rent",
#             "price": 3200.0,
#             "priceByArea": 29.0,
#             "propertyCode": "96097212",
#             "propertyType": "flat",
#             "province": "Madrid",
#             "rooms": 2,
#             "showAddress": false,
#             "size": 110.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Chueca-Justicia, Madrid",
#                 "title": "Piso"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/11/93/17/936648949.jpg",
#             "topNewDevelopment": false,
#             "url": "https://www.idealista.com/inmueble/96097212/"
#         },
#         {
#             "address": "Calle de la Madera",
#             "bathrooms": 1,
#             "country": "es",
#             "description": "Piso en alquiler en Malasa\u00f1a Piso de 1 dormitorio en edificio totalmente reformado. El dormitorio principal cuenta con cama doble con canap\u00e9, ventilaci\u00f3n natural con acceso a un balc\u00f3n y grandes armarios empotrados. Nada m\u00e1s acceder a la vivienda nos encontramos con el espacio de sal\u00f3n-comedor-cocina. El sal\u00f3n cuenta con mobiliario variado as\u00ed como un sof\u00e1 cama de grandes dimensiones y una smart TV de gran amplitud y salida al exterior por dos balcones con vistas. En la cocina encontramos todos los electrodom\u00e9sticos panelados, conservando as\u00ed la cuidada est\u00e9tica de todo el espacio. La casa viene equipada con todo lo necesario y comodidades para entrar a vivir. Por otro lado se incluyen los suministros y el wifi as\u00ed como una limpieza semanal. El tipo de calefacci\u00f3n y aire acondicionado se realiza por conductos en todas las estancias por bomba de fr\u00edo/calor. Acepta tanto corta como larga estancia.",
#             "detailedType": {
#                 "typology": "flat"
#             },
#             "distance": "985",
#             "district": "Centro",
#             "exterior": true,
#             "externalReference": "AM2110094",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": false,
#             "hasStaging": false,
#             "hasVideo": false,
#             "latitude": 40.422122,
#             "longitude": -3.7030696,
#             "municipality": "Madrid",
#             "neighborhood": "Malasa\u00f1a-Universidad",
#             "newDevelopment": false,
#             "numPhotos": 19,
#             "operation": "rent",
#             "price": 2350.0,
#             "priceByArea": 34.0,
#             "propertyCode": "95660319",
#             "propertyType": "flat",
#             "province": "Madrid",
#             "rooms": 1,
#             "showAddress": false,
#             "size": 70.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Malasa\u00f1a-Universidad, Madrid",
#                 "title": "Piso en Calle de la Madera"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/10/a5/70/924628976.jpg",
#             "topNewDevelopment": false,
#             "url": "https://www.idealista.com/inmueble/95660319/"
#         },
#         {
#             "address": "barrio Malasa\u00f1a-Universidad",
#             "bathrooms": 1,
#             "country": "es",
#             "description": "Piso en alquiler en Alberto Aguilera Nuevo a estrenar, el piso est\u00e1 distribuido en una entrada con paso al sal\u00f3n a la izquierda y cocina abierta americana a la izquierda; nueva a estrenar con materiales modernos en color negro, que hacen que sea un espacio muy est\u00e9tico. Esta zona de la casa, tiene ventanas amplias. En frente de la zona de estar, a mano izquierda el cuarto de ba\u00f1o con ducha y radiador de toallas, todo combinado en blanco y negro, con suelo de azulejos moderno en estos colores. Al lado de este, una de las habitaciones, con armarios empotrados y espacio para una cama de matrimonio y una mesa de estudio o banco. Al otro lado de la zona de estar, la segunda habitaci\u00f3n con armarios empotrados. El piso esta reci\u00e9n reformado, es muy luminoso y est\u00e1 situado en una zona que dispone de transporte p\u00fablico a toda la ciudad, supermercados de toda clase y todo tipo de comercios.",
#             "detailedType": {
#                 "typology": "flat"
#             },
#             "distance": "92",
#             "district": "Centro",
#             "exterior": true,
#             "externalReference": "AM2111157",
#             "floor": "3",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": false,
#             "hasStaging": false,
#             "hasVideo": true,
#             "latitude": 40.4296398,
#             "longitude": -3.7087133,
#             "municipality": "Madrid",
#             "neighborhood": "Malasa\u00f1a-Universidad",
#             "newDevelopment": false,
#             "numPhotos": 25,
#             "operation": "rent",
#             "price": 1150.0,
#             "priceByArea": 23.0,
#             "propertyCode": "96075276",
#             "propertyType": "flat",
#             "province": "Madrid",
#             "rooms": 2,
#             "showAddress": false,
#             "size": 49.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Malasa\u00f1a-Universidad, Madrid",
#                 "title": "Piso"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/eb/79/99/936095020.jpg",
#             "topNewDevelopment": false,
#             "url": "https://www.idealista.com/inmueble/96075276/"
#         },
#         {
#             "address": "Plaza de Espa\u00f1a",
#             "bathrooms": 1,
#             "country": "es",
#             "description": "Piso en alquiler con terraza en Plaza de Espa\u00f1a En uno de los edificios m\u00e1s emblem\u00e1ticos de Madrid, encontramos este impresionante piso de 87 m\u00b2 con una gran terraza con vistas al Palacio Real y la Gran V\u00eda. El piso se compone de dos habitaciones, sal\u00f3n-comedor, un ba\u00f1o completo y cocina. Desde la puerta de acceso damos paso a un amplio hall que da paso al amplio sal\u00f3n-comedor, que es completamente exterior y gracias a su altura tiene mucha luminosidad. La cocina est\u00e1 completamente equipada con electrodom\u00e9sticos de alta gama. En la zona de noche encontramos las dos habitaciones. El cuarto de ba\u00f1o es completo con ducha, y lo comparten ambas habitaciones. Por \u00faltimo el piso goza de unas impresionantes vistas gracias a su terraza privada. El piso est\u00e1 completamente amueblado con mobiliario de alta calidad, tiene suelo de parquet, aire acondicionado por conductos y ventanas de doble cristal. La finca cuenta con conserje 24\u202fh, ascensor, piscina, gimnasio, jacuzzi y sol\u00e1rium. El edificio est\u00e1 situado en un enclave privilegiado de Madrid con excelentes comunicaciones y con multitud de comercios cercanos. Disponible a partir del 13 de enero.",
#             "detailedType": {
#                 "typology": "flat"
#             },
#             "distance": "626",
#             "district": "Moncloa",
#             "exterior": true,
#             "externalReference": "AM2111098",
#             "floor": "17",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": false,
#             "hasStaging": false,
#             "hasVideo": true,
#             "latitude": 40.4238122,
#             "longitude": -3.7108753,
#             "municipality": "Madrid",
#             "neighborhood": "Arg\u00fcelles",
#             "newDevelopment": false,
#             "numPhotos": 25,
#             "operation": "rent",
#             "price": 2500.0,
#             "priceByArea": 23.0,
#             "propertyCode": "95974068",
#             "propertyType": "flat",
#             "province": "Madrid",
#             "rooms": 2,
#             "showAddress": false,
#             "size": 107.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Arg\u00fcelles, Madrid",
#                 "title": "Piso en Plaza de Espa\u00f1a"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/ab/cb/29/933213988.jpg",
#             "topNewDevelopment": false,
#             "url": "https://www.idealista.com/inmueble/95974068/"
#         },
#         {
#             "address": "barrio Gaztambide",
#             "bathrooms": 2,
#             "country": "es",
#             "description": "Piso en alquiler en Arg\u00fcelles Estupendo piso, exterior con techos altos, sin amueblar de 152\u202fm\u00b2. Tiene un amplio hall con gran armario en la entrada, el sal\u00f3n est\u00e1 dividido en dos estancias con balc\u00f3n y doble acristalamiento que lo a\u00edslan del ruido. A continuaci\u00f3n, una ampl\u00edsima habitaci\u00f3n polivalente con chimenea decorativa. El dormitorio principal con cuarto de ba\u00f1o en suite y una tercera habitaci\u00f3n dan a un patio interior. Todos tienen grandes armarios empotrados. El ba\u00f1o secundario con ducha se encuentra en el pasillo. Al fondo de la vivienda encontramos una amplia cocina equipada con todos los electrodom\u00e9sticos y gran capacidad de almacenaje. La calefacci\u00f3n de gas natural es individual. Magnifica ubicaci\u00f3n, pr\u00f3ximo a supermercados, centros comerciales, peque\u00f1o comercio y transportes p\u00fablicos a pie de calle. Disponibilidad inmediata.",
#             "detailedType": {
#                 "typology": "flat"
#             },
#             "distance": "356",
#             "district": "Chamber\u00ed",
#             "exterior": true,
#             "externalReference": "AM2112032",
#             "floor": "4",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": false,
#             "hasStaging": false,
#             "hasVideo": false,
#             "latitude": 40.42889,
#             "longitude": -3.7139182,
#             "municipality": "Madrid",
#             "neighborhood": "Gaztambide",
#             "newDevelopment": false,
#             "numPhotos": 25,
#             "operation": "rent",
#             "price": 1950.0,
#             "priceByArea": 13.0,
#             "propertyCode": "96166105",
#             "propertyType": "flat",
#             "province": "Madrid",
#             "rooms": 3,
#             "showAddress": false,
#             "size": 152.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Gaztambide, Madrid",
#                 "title": "Piso"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/af/e1/9b/938680910.jpg",
#             "topNewDevelopment": false,
#             "url": "https://www.idealista.com/inmueble/96166105/"
#         },
#         {
#             "address": "Calle de Montele\u00f3n",
#             "bathrooms": 1,
#             "country": "es",
#             "description": "Alquilares pone a su disposici\u00f3n el alquiler de este magn\u00edfico piso semiamueblado en planta baja en la calle Montele\u00f3n, en pleno Chamber\u00ed, y a escasos metros de la Glorieta de Bilbao. El inmueble tiene un amplio dormitorio principal di\u00e1fano con armario, al cual se accede desde la escalera del sal\u00f3n, un amplio ba\u00f1o con ba\u00f1era, sal\u00f3n comedor con cocina integrada y equipada con electrodom\u00e9sticos, y una segunda habitaci\u00f3n m\u00e1s peque\u00f1a. Cuenta con caldera individual de gas natural.  Los suelos son de tarima de primera calidad, y la pintura es blanca lisa. El estado del inmueble es para entrar a vivir.  Tiene adem\u00e1s, un patio de 8 m2 de uso y disfrute, con salida desde el sal\u00f3n. Ser\u00e1n requisitos necesarios la presentaci\u00f3n del contrato de trabajo y tres \u00faltimas n\u00f3minas para el an\u00e1lisis de capacidad financiera y de solvencia, no siendo posible el alquiler de este inmueble sin el an\u00e1lisis de dicha documentaci\u00f3n, puesto que el alquiler de este inmueble lleva aparejada la emisi\u00f3n de p\u00f3liza de impago de rentas.  Condiciones econ\u00f3micas del alquiler: mes en curso, mes de garant\u00eda adicional, mes fianza y mes de intermediaci\u00f3n inmobiliaria(+iva).",
#             "detailedType": {
#                 "typology": "flat"
#             },
#             "distance": "656",
#             "district": "Chamber\u00ed",
#             "exterior": true,
#             "externalReference": "DC_252_51",
#             "floor": "bj",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": false,
#             "hasStaging": false,
#             "hasVideo": false,
#             "latitude": 40.4321213,
#             "longitude": -3.7028852,
#             "municipality": "Madrid",
#             "neighborhood": "Trafalgar",
#             "newDevelopment": false,
#             "numPhotos": 11,
#             "operation": "rent",
#             "price": 900.0,
#             "priceByArea": 15.0,
#             "propertyCode": "96130118",
#             "propertyType": "flat",
#             "province": "Madrid",
#             "rooms": 1,
#             "showAddress": false,
#             "size": 60.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Trafalgar, Madrid",
#                 "title": "Piso en Calle de Montele\u00f3n"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/0a/4b/c1/937624153.jpg",
#             "topNewDevelopment": false,
#             "url": "https://www.idealista.com/inmueble/96130118/"
#         },
#         {
#             "address": "Calle de Fern\u00e1ndez de los R\u00edos",
#             "bathrooms": 1,
#             "country": "es",
#             "description": "Disponibilidad Inmediata  Piso de 2 dormitorios dobles ideal para compartir o estudiantes completamente amueblado, sal\u00f3n con cocina tipo americana integrada equipada con electrodom\u00e9sticos, ba\u00f1o con plato de ducha. El piso de ha reforma reciente con buenas calidades, suelos de tarima, ventanas con climalit, paredes lisas, todas las estancias, incluido el ba\u00f1o, tienen ventana. Situado al lado de la plaza de Quevedo, muy bien comunicado con metro y varias l\u00edneas de autobuses. Los datos espec\u00edficos sobre la finca publicada, pueden ser aproximados, por ello no son vinculantes ni contractuales, se muestran a t\u00edtulo informativo. Ponemos nuestro esfuerzo d\u00eda tras d\u00eda en ofrecer el mejor servicio y realizar nuestra actividad con el m\u00ednimo riesgo. Nuestras visitas se realizan con las m\u00e1ximas garant\u00edas y medidas de seguridad posibles para no poner en riesgo a nadie en el momento que estamos viviendo. Nuestras propiedades cuentan con medidas de higiene y desinfecci\u00f3n necesarias al igual que nuestro equipo de profesionales para realizar la visita de forma segura y todo el trato con el cliente. Reserve su cita para venir a verlo dentro de nuestro amplio horario, incluidos fines de semana.  Estaremos encantados de atenderle.",
#             "detailedType": {
#                 "typology": "flat"
#             },
#             "distance": "743",
#             "district": "Chamber\u00ed",
#             "exterior": false,
#             "externalReference": "4526-06168",
#             "floor": "1",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": false,
#             "hasPlan": false,
#             "hasStaging": false,
#             "hasVideo": true,
#             "latitude": 40.4357587,
#             "longitude": -3.7071003,
#             "municipality": "Madrid",
#             "neighborhood": "Arapiles",
#             "newDevelopment": false,
#             "numPhotos": 20,
#             "operation": "rent",
#             "price": 950.0,
#             "priceByArea": 19.0,
#             "propertyCode": "96169448",
#             "propertyType": "flat",
#             "province": "Madrid",
#             "rooms": 2,
#             "showAddress": false,
#             "size": 50.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Arapiles, Madrid",
#                 "title": "Piso en Calle de Fern\u00e1ndez de los R\u00edos"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/de/d2/5b/938810395.jpg",
#             "topNewDevelopment": false,
#             "url": "https://www.idealista.com/inmueble/96169448/"
#         },
#         {
#             "address": "Calle de Amaniel",
#             "bathrooms": 1,
#             "country": "es",
#             "description": "Precioso estudio situado en pleno barrio de Malasa\u00f1a-Conde Duque, una de las mejores zonas del barrio central de Madrid, con todo tipo de comercios, supermercados, y zona de ocio muy cerca de la vivienda, aunque la zona de la casa es muy tranquila. Metro noviciado a 350 m y varias l\u00edneas de autobuses muy cerca de la casa. Estudio amplio, para entrar a vivir, se alquila amueblado, suelos de tarima, cocina equipada, ventanas climalit, aire acondicionado. Mes corriente, 1 mes de fianza y mes de agencia.",
#             "detailedType": {
#                 "subTypology": "studio",
#                 "typology": "flat"
#             },
#             "distance": "396",
#             "district": "Centro",
#             "exterior": false,
#             "floor": "1",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": false,
#             "hasPlan": false,
#             "hasStaging": false,
#             "hasVideo": false,
#             "latitude": 40.4258193,
#             "longitude": -3.7100233,
#             "municipality": "Madrid",
#             "neighborhood": "Malasa\u00f1a-Universidad",
#             "newDevelopment": false,
#             "numPhotos": 15,
#             "operation": "rent",
#             "price": 650.0,
#             "priceByArea": 22.0,
#             "propertyCode": "96249678",
#             "propertyType": "studio",
#             "province": "Madrid",
#             "rooms": 0,
#             "showAddress": false,
#             "size": 30.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Malasa\u00f1a-Universidad, Madrid",
#                 "title": "Estudio en Calle de Amaniel"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/23/d6/2b/941655915.jpg",
#             "topNewDevelopment": false,
#             "url": "https://www.idealista.com/inmueble/96249678/"
#         },
#         {
#             "address": "Calle de Quintana",
#             "bathrooms": 3,
#             "country": "es",
#             "description": "Piso en alquiler con terraza en Arg\u00fcelles Precioso piso muy acogedor y sin amueblar, ubicado en un edificio de construcci\u00f3n antigua que posee un encanto \u00fanico, en una de las zonas m\u00e1s emblem\u00e1ticas de Madrid, junto al Templo de Debod, Paseo Pintor Rosales y Parque del Oeste, cercano a zona comercial y de ocio, muy bien comunicado con toda la red de metro de Madrid y autobuses. La vivienda consta de un amplio hall abierto que da acceso a la zona de d\u00eda y en el que se integran una bonita cocina moderna y amplio sal\u00f3n, con amplios ventanales. A trav\u00e9s de un ancho pasillo se distribuye el resto de la vivienda, un lavadero y una peque\u00f1a terraza. La zona de descanso posee cuatro dormitorios y tres ba\u00f1os completos. La vivienda destaca por su ornamentaci\u00f3n con molduras de l\u00edneas cl\u00e1sicas especialmente elegantes, techos altos y suelos de madera originales en impecable estado. La propiedad dispone de calefacci\u00f3n central y portero f\u00edsico. Disponible a partir de diciembre.",
#             "detailedType": {
#                 "typology": "flat"
#             },
#             "distance": "759",
#             "district": "Moncloa",
#             "exterior": true,
#             "externalReference": "AM2111082",
#             "floor": "1",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": false,
#             "hasStaging": false,
#             "hasVideo": false,
#             "latitude": 40.4285292,
#             "longitude": -3.7186515,
#             "municipality": "Madrid",
#             "neighborhood": "Arg\u00fcelles",
#             "newDevelopment": false,
#             "numPhotos": 25,
#             "operation": "rent",
#             "price": 2200.0,
#             "priceByArea": 12.0,
#             "propertyCode": "95939690",
#             "propertyType": "flat",
#             "province": "Madrid",
#             "rooms": 4,
#             "showAddress": false,
#             "size": 180.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Arg\u00fcelles, Madrid",
#                 "title": "Piso en Calle de Quintana"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/26/26/7c/932296480.jpg",
#             "topNewDevelopment": false,
#             "url": "https://www.idealista.com/inmueble/95939690/"
#         },
#         {
#             "address": "Calle Gran V\u00eda",
#             "bathrooms": 2,
#             "country": "es",
#             "description": "Piso en alquiler amueblado en Gran V\u00eda Vivienda de obra nueva de 122 m\u00b2 en plena Gran V\u00eda, junto a plaza de Espa\u00f1a. Se alquila amueblada. Desde la entrada, accedemos al primer dormitorio, con cama individual y ba\u00f1o completo en suite. Avanzando se encuentra el dormitorio principal. Tambi\u00e9n con ba\u00f1o en suite, zona de vestidor, cama doble y televisor instalado. Este dormitorio tiene la posibilidad de conexi\u00f3n directa con el sal\u00f3n mediante puertas correderas. Tambi\u00e9n podemos acceder al sal\u00f3n comedor desde el pasillo. La cocina est\u00e1 equipada con todos los electrodom\u00e9sticos de alta gama, incluyendo lavaplatos, lavadora-secadora, horno y microondas. Todas las estancias cuentan con aire acondicionado por conductos y la calefacci\u00f3n es individual por suelo radiante. La finca dispone de servicio de porter\u00eda, gimnasio y piscina en la azotea con espectaculares vistas a la Gran V\u00eda. Se incluye una plaza de parking robotizada en la misma finca. Est\u00e1 ubicado en una zona con excelentes servicios, oferta de restauraci\u00f3n y muy buenas comunicaciones. Disponible el 15 de enero de 2022.",
#             "detailedType": {
#                 "typology": "flat"
#             },
#             "distance": "597",
#             "district": "Centro",
#             "exterior": true,
#             "externalReference": "AM2112040",
#             "floor": "8",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": false,
#             "hasStaging": false,
#             "hasVideo": false,
#             "latitude": 40.4241391,
#             "longitude": -3.7081923,
#             "municipality": "Madrid",
#             "neighborhood": "Malasa\u00f1a-Universidad",
#             "newDevelopment": false,
#             "numPhotos": 19,
#             "operation": "rent",
#             "parkingSpace": {
#                 "hasParkingSpace": true,
#                 "isParkingSpaceIncludedInPrice": true
#             },
#             "price": 3100.0,
#             "priceByArea": 25.0,
#             "propertyCode": "96195079",
#             "propertyType": "flat",
#             "province": "Madrid",
#             "rooms": 2,
#             "showAddress": false,
#             "size": 122.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Malasa\u00f1a-Universidad, Madrid",
#                 "title": "Piso en Calle Gran V\u00eda"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/53/c3/f9/940013972.jpg",
#             "topNewDevelopment": false,
#             "url": "https://www.idealista.com/inmueble/96195079/"
#         },
#         {
#             "address": "barrio Arapiles",
#             "bathrooms": 1,
#             "country": "es",
#             "description": "Piso en alquiler en Arapiles  DISPONIBLE EN MARZO DE 2022. Acogedor apartamento reci\u00e9n reformado en Arapiles. El apartamento consta de dos dormitorios con armarios empotrados, cocina americana completamente equipada con nevera lavavajillas, horno, microondas y lavadora. El sal\u00f3n tiene una gran ventana por la que entra mucha luz y est\u00e1 equipado con un sof\u00e1 para dos personas y televisi\u00f3n. El ba\u00f1o que comparten las dos habitaciones es con ducha. El piso tiene aire acondicionado y portero f\u00edsico. El piso esta reformado y amueblado cuidando todos los detalles con muy buen gusto, listo para entrar a vivir con todo lo necesario. El piso se encuentra en una de las mejores zonas residenciales de Madrid muy cercano a la zona universitaria, al centro y muy bien comunicado por transporte publico teniendo a escasos metros la estaci\u00f3n de metro de Quevedo y las l\u00edneas de autob\u00fas 16 y 61.",
#             "detailedType": {
#                 "typology": "flat"
#             },
#             "distance": "557",
#             "district": "Chamber\u00ed",
#             "exterior": false,
#             "externalReference": "AM2112041",
#             "floor": "6",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": false,
#             "hasStaging": false,
#             "hasVideo": true,
#             "latitude": 40.4343917,
#             "longitude": -3.7099313,
#             "municipality": "Madrid",
#             "neighborhood": "Arapiles",
#             "newDevelopment": false,
#             "numPhotos": 25,
#             "operation": "rent",
#             "price": 1400.0,
#             "priceByArea": 28.0,
#             "propertyCode": "96199052",
#             "propertyType": "flat",
#             "province": "Madrid",
#             "rooms": 2,
#             "showAddress": false,
#             "size": 50.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Arapiles, Madrid",
#                 "title": "Piso"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/b0/90/e7/940121667.jpg",
#             "topNewDevelopment": false,
#             "url": "https://www.idealista.com/inmueble/96199052/"
#         },
#         {
#             "address": "Calle de Mart\u00edn de los Heros",
#             "bathrooms": 1,
#             "country": "es",
#             "description": "En el barrio de Moncloa, esquina con Plaza Espa\u00f1a y muy cerca de la Gran V\u00eda de Madrid, se alquila estudio luminoso en edificio con conserje y ascensor. La vivienda dispone de un recibidor con armario empotrado, una estancia amplia desde donde accedemos a un ba\u00f1o completo, una peque\u00f1a cocina y una terraza cerrada. La vivienda se alquila sin muebles salvo la cocina que dispone de lavadora y nevera. Lo honorarios de la agencia son de una mensualidad. Si quieres vivir cerca del centro de Madrid, no dudes en visitar este piso!",
#             "detailedType": {
#                 "subTypology": "studio",
#                 "typology": "flat"
#             },
#             "distance": "623",
#             "district": "Moncloa",
#             "exterior": false,
#             "externalReference": "0015-06127",
#             "floor": "1",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": false,
#             "hasStaging": false,
#             "hasVideo": false,
#             "latitude": 40.4250214,
#             "longitude": -3.7143863,
#             "municipality": "Madrid",
#             "neighborhood": "Arg\u00fcelles",
#             "newDevelopment": false,
#             "numPhotos": 14,
#             "operation": "rent",
#             "price": 680.0,
#             "priceByArea": 17.0,
#             "propertyCode": "96244745",
#             "propertyType": "studio",
#             "province": "Madrid",
#             "rooms": 0,
#             "showAddress": false,
#             "size": 41.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Arg\u00fcelles, Madrid",
#                 "title": "Estudio en Calle de Mart\u00edn de los Heros"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/c0/34/4d/941554276.jpg",
#             "topNewDevelopment": false,
#             "url": "https://www.idealista.com/inmueble/96244745/"
#         },
#         {
#             "address": "barrio Arapiles",
#             "bathrooms": 1,
#             "country": "es",
#             "description": "REF 98387 Fant\u00e1stico estudio en alquiler con superficie de 30 m2, situado en la tercera planta exterior de la finca. Muy luminoso y tranquilo, soleado La vivienda consta de: - sal\u00f3n comedor - cocina equipada con frigor\u00edfico, lavadora, etc - 1 ba\u00f1o completo Dispone de cuatro armarios, wifici, electricidad, calefacci\u00f3n central, agua caliente.  Gastos de comunidad e ibi incluidos en el precio  Finca con tres ascensores. Se encuentra en una zona muy c\u00e9ntrico, autobuses y metro Quevedo pr\u00e1cticamente en la puerta, junto a el corte ingles, cines, supermercados, etc El barrio de Arapiles pertenece al distrito de Chamber\u00ed, en el norte de Madrid. Sus l\u00edmites son, por el norte, la calle de Cea Berm\u00fadez; por el este, la calle de Bravo Murillo y la calle de San Bernardo; por el sur, la calle de Alberto Aguilera; y, por el oeste, la calle de Blasco de Garay. Las dos v\u00edas principales del barrio son la calle de Vallehermoso, que act\u00faa como eje, y la calle de Bravo Murillo. Hay una buena comunicaci\u00f3n de autobuses y metro (San Bernardo, Quevedo, Canal e Islas Filipinas). El barrio est\u00e1 relativamente cerca del centro de Madrid, por lo que es posible dar un agradable paseo hasta all\u00ed. Para m\u00e1s informaci\u00f3n, contactar con el equipo de AreaCasa.",
#             "detailedType": {
#                 "subTypology": "studio",
#                 "typology": "flat"
#             },
#             "distance": "612",
#             "district": "Chamber\u00ed",
#             "exterior": true,
#             "externalReference": "98387",
#             "floor": "3",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": false,
#             "hasStaging": false,
#             "hasVideo": false,
#             "latitude": 40.4348793,
#             "longitude": -3.7101594,
#             "municipality": "Madrid",
#             "neighborhood": "Arapiles",
#             "newDevelopment": false,
#             "numPhotos": 12,
#             "operation": "rent",
#             "price": 690.0,
#             "priceByArea": 23.0,
#             "propertyCode": "96245310",
#             "propertyType": "studio",
#             "province": "Madrid",
#             "rooms": 0,
#             "showAddress": false,
#             "size": 30.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Arapiles, Madrid",
#                 "title": "Estudio"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/3c/cc/10/941532779.jpg",
#             "topNewDevelopment": false,
#             "url": "https://www.idealista.com/inmueble/96245310/"
#         }
#     ],
#     "hiddenResults": false,
#     "itemsPerPage": 20,
#     "lowerRangePosition": 0,
#     "numPaginations": 0,
#     "paginable": true,
#     "summary": [
#         "Alquilar",
#         "Viviendas",
#         "barrio Malasa\u00f1a-Universidad, Madrid",
#         "Todos los precios",
#         "Todos los tama\u00f1os"
#     ],
#     "total": 854,
#     "totalPages": 43,
#     "upperRangePosition": 20
# }
