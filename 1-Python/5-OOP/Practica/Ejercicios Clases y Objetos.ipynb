# %% [markdown]
# ![imagen](./img/ejercicios.png)
#
# # Ejercicios Clases y Objetos

# %% [markdown]
# ## Ejercicio 1
# Somos una empresa que tiene varias tiendas de electrodomesticos. Necesitamos un programa para manejar las tiendas, ver las ventas que han tenido, cuántos empleados hay, etc... Para ello vamos a modelizar la tienda en una clase, que tendrá las siguientes características:
# * Nombre clase: "Tienda"
# * Atributos comunes:
#     * Tipo: "Electrodomésticos"
#     * Abierta: True
# * Atributos propios de cada tienda:
#     * Nombre - String
#     * Dirección - String
#     * Número de empleados - int
#     * Ventas ultimos 3 meses - Lista de 3 numeros
# * Método para calcular las ventas de todos los meses, que devuelva un numero con todas las ventas.
# * Método que calcula la media de ventas de los ultimos meses, por empleado
# * Método que devuelve en un string el nombre de la tienda, junto con su dirección.
# * Método que obtiene las ventas del último mes.
# * Método para dar una proyección de las ventas en caso de haber invertido X dinero en marketing en esa tienda. Siendo X el parámetro de entrada. Si X es menor de 1000, las ventas de los ultimos 3 meses hubiesen sido de (1.2 x ventas), si es mayor o igual de 1000, las ventas hubiesen sido de (1.5 x venta). El método reescribe el atributo de ventas en los últimos 3 meses, y además devuelve las ventas con el aumento.
#
# Se pide:
# 1. Implementar la clase "Tienda"
# 2. Crear tres tiendas con datos inventados
# 3. Comprueba en al menos una de ellas, todo lo implementado en la clase tienda (sus atributos, media de ventas, ventas/empleado...)
# 3. Calcular las ventas del último mes de todas las tiendas. Para ello usa el bucle `for`
# 4. Imprime por pantalla los nombres de las tiendas cuya dirección lleve el string "Avenida"
# 5. Seguro que ya has hecho este apartado... Documenta la clase :)

# %%
# 1)

import copy

class Tienda:
    '''
    Clase que implementa una tienda de nuestra cadena.
    
    '''
    tipo = "Electrodomésticos"
    abierta = True
    def __init__(self, nombre, direccion, empleados, ventas):
        self.nombre= nombre
        self.direccion = direccion
        self.empleados = empleados
        self.ventas = ventas
        
    def ventasTotales(self):
        '''
        Calcula los ventas de los tres últimos meses de la tienda. 
        '''
        return sum(self.ventas)
    
    def mediaVentasEmpleado(self):
        '''
        Calcula las ventas por empleado de los tres últimos meses de la tienda. 
        '''
        return self.ventasTotales() / self.empleados
        
    def razonSocial(self):
        '''
        Devuelve una cadena con el nombre y la dirección de la tienda 
        '''
        return f'{self.nombre},\nDirección: {self.direccion}'
    
    def ventasMes(self, mes=None):
        '''
        Devuelve las ventas de un mes del último trimestre.
        Si no se especifica el mes se devuelve el último mes
        '''
        if mes != None:
            mes = None if mes <= 0 or mes > 3 else  mes
        return self.ventas[-1] if mes == None else self.ventas[mes-1]
    
    def proyectarVentas(self, x):
        '''
        Devuelve una proyección de las ventas basada en las ventas del último trimestre
        '''
        proyeccion = copy.copy(self.ventas)
        aumento = 1.2 if x < 1000 else  1.5 
        for i, ventaMes in enumerate(proyeccion):
            proyeccion[i] = ventaMes * aumento
        return sum(proyeccion)

# %%
# 2)
lista_tiendas = []
lista_tiendas.append(Tienda("Tienda 1", "Calle de Uno, 1", 3, [3000, 4000, 5000]))
lista_tiendas.append(Tienda("Tienda 2", "Avenida de Dos, 2", 6, [6000, 9000, 15000]))
lista_tiendas.append(Tienda("Tienda 3", "Calle de Tres, 3", 4, [5000, 4000, 7000]))

print(f'\n3) Datos tiendas')
for tienda in lista_tiendas:
    print(f'\n{tienda.razonSocial()}')
    print(f'Ventas totales {tienda.ventasTotales()}€')
    print(f'Empleados {tienda.empleados}')
    print(f'Ventas por empleado {tienda.mediaVentasEmpleado()}€')
    print(f'Proyección de ventas invirtiendo 900€ en marketing-> {tienda.proyectarVentas(900)}€')
    print(f'Proyección de ventas invirtiendo 1000€ en marketing -> {tienda.proyectarVentas(1000)}€')


total_mes = 0
for tienda in lista_tiendas:
    total_mes += tienda.ventasMes()
print(f'\n4) Ventas totales último mes {total_mes}€')

print(f'\n5) Tiendas ubicadas en una avenida')
for tienda in lista_tiendas:
    if 'Avenida'.lower() in tienda.direccion.lower():
        print(tienda.nombre) 
        
print(f'\n6) \n')        
help(Tienda)
# Out:
# 3) Datos tiendas
#
# Tienda 1,
# Dirección: Calle de Uno, 1
# Ventas totales 12000€
# Empleados 3
# Ventas por empleado 4000.0€
# Proyección de ventas invirtiendo 900€ en marketing-> 14400.0€
# Proyección de ventas invirtiendo 1000€ en marketing -> 18000.0€
#
# Tienda 2,
# Dirección: Avenida de Dos, 2
# Ventas totales 30000€
# Empleados 6
# Ventas por empleado 5000.0€
# Proyección de ventas invirtiendo 900€ en marketing-> 36000.0€
# Proyección de ventas invirtiendo 1000€ en marketing -> 45000.0€
#
# Tienda 3,
# Dirección: Calle de Tres, 3
# Ventas totales 16000€
# Empleados 4
# Ventas por empleado 4000.0€
# Proyección de ventas invirtiendo 900€ en marketing-> 19200.0€
# Proyección de ventas invirtiendo 1000€ en marketing -> 24000.0€
#
# 4) Ventas totales último mes 27000€
#
# 5) Tiendas ubicadas en una avenida
# Tienda 2
#
# 6)
#
# Help on class Tienda in module __main__:
#
# class Tienda(builtins.object)
#  |  Tienda(nombre, direccion, empleados, ventas)
#  |
# ...

# %% [markdown]
# ## Ejercicio 2
# En este ejercicio vamos a implementar una clase *Perro* en Python. La clase tiene las siguientes características:
# * Cosas que sabemos seguro que tiene un perro
#     * Tiene 4 patas
#     * 2 orejas
#     * 2 ojos
#     * Una velocidad de 0. Por defecto, el perro está parado
# * Cuando se inicialice:
#     * El perro será de una determinada raza
#     * Por defecto tendrá pelo "Marrón", a no ser que se diga lo contrario.
#     * Por defecto no tendrá dueño, a no ser que se diga lo contrario.
#
# * Dispondrá también de un método llamado andar, que tiene un argumento de entrada (aumento_velocidad). Este valor se le sumará a la velocidad que ya llevaba el perro.
# * Necesita otro método (parar), donde pondremos la velocidad a 0.
# * Otro método llamado "ladrar", que tendrá un argumento de entrada, y la salida será el siguiente string: "GUAU!" + el argumento de entrada.
#
#
# Se pide:
# * Implementa la clase *Perro*
# * Crea un objeto de tipo *Perro*, sin dueño
# * Comprueba que están bien todos sus atributos
# * Prueba que ande, y comprueba su velocidad
# * Páralo
# * Documenta la clase *Perro*

# %%
#1)

class Perro:
    '''
    Clase para crear objetos de tipo Perro.

    '''   
    patas = 4
    orejas = 2
    velocidad = 0    
    
    
    def __init__(self, raza, color = "Marrón", propietario = "Sin dueño"):
        '''
        Inicializa un objeto de tipo Perro.
        raza : Mandatory
        color : Optional. "Marrón" by default
        propietario : Optional. "Sin dueño" by default
        '''            
        self.raza = raza
        self.color = color
        self.propietario = propietario
        
    def andar(self, aumento_velocidad):
        '''
        Añade velocidad a un objeto de tipo Perro
        '''                
        self.velocidad += aumento_velocidad
    
    def parar(self):
        '''
        Establece a 0 la velocidad de un objeto Perro
        '''               
        self.velocidad = 0
    
    def ladrar(self, entrada):
        '''
        
        '''
        return "GUAU! " + entrada

# %%
# 2) 
perro_menso = Perro("Galgo")

# %%
# 3)

print(vars(perro_menso))
# Out:
# {'raza': 'Galgo', 'color': 'Marrón', 'propietario': 'Sin dueño'}

# %%
perro_menso.andar(5)
print(vars(perro_menso))
# Out:
# {'raza': 'Galgo', 'color': 'Marrón', 'propietario': 'Sin dueño', 'velocidad': 5}

# %%
perro_menso.parar()
print(vars(perro_menso))
# Out:
# {'raza': 'Galgo', 'color': 'Marrón', 'propietario': 'Sin dueño', 'velocidad': 0}

# %%
help(Perro)
# Out:
# Help on class Perro in module __main__:
#
# class Perro(builtins.object)
#  |  Perro(raza, color='Marrón', propietario='Sin dueño')
#  |
#  |  Clase para crear objetos de tipo Perro.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, raza, color='Marrón', propietario='Sin dueño')
#  |      Inicializa un objeto de tipo Perro.
#  |      raza : Mandatory
#  |      color : Optional. "Marrón" by default
#  |      propietario : Optional. "Sin dueño" by default
#  |
#  |  andar(self, aumento_velocidad)
#  |      Añade velocidad a un objeto de tipo Perro
#  |
#  |  ladrar(self, entrada)
#  |
#  |  parar(self)
#  |      Establece a 0 la velocidad de un objeto Perro
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
# ...
